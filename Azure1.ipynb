# %% [markdown]
# <a href="https://colab.research.google.com/github/Prashantlondhe123/BIG-DATA/blob/main/Azure1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Cloud Computing

# %% [markdown]
# >Cloud computing is web based computing that allows business and individuals to consume computing resources.

# %% [markdown]
# ##Type of cloud computing

# %% [markdown]
# - Public
# - Private
# - Hybrid
# - Community Cloud

# %% [markdown]
# ## Type of cloud services

# %% [markdown]
# - IAAS(Infrastructure-as-a-Service)
# - PAAS(Platforms-as-a-Service)
# - SAAS(Software-as-a-Service)

# %% [markdown]
# ## List of Cloud Service Providers

# %% [markdown]
# - Amazon Web Service (AWS)
# - ServerSpace.
# - Microsoft Azure.
# - Google Cloud Platform.
# - IBM Cloud Services.
# - Adobe Creative Cloud.
# - Kamatera.
# - VMware........................................................................

# %% [markdown]
# ## What is azure?

# %% [markdown]
# > Azure is a public cloud computing platform—with solutions including Infrastructure as a Service (IaaS), Platform as a Service (PaaS), and Software as a Service (SaaS) that can be used for services such as analytics, virtual computing, storage, networking, and much more.

# %% [markdown]
# #ADF

# %% [markdown]
# >Azure Data Factory is Azure's cloud ETL service for scale-out serverless data integration and data transformation.

# %% [markdown]
# ## What is Azure storage?

# %% [markdown]
# > The Azure Storage platform is Microsoft's cloud storage solution for modern data storage scenarios. Azure Storage offers highly available, massively scalable, durable, and secure storage for a variety of data objects in the clou
